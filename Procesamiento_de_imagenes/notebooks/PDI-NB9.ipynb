# %% [markdown]
# # Aritmética de pixels

# %%
import imageio.v3 as iio
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_2)

# %%
img_1 = iio.imread('imageio:chelsea.png') / 255
img_2 = iio.imread('imageio:coffee.png') / 255

img_2 = img_2[0:300, 100:551, :]

print(img_1.shape)
print(img_2.shape)
print(img_1.dtype)

suma =  img_1 +  img_2

# suma = np.clip(suma, 0, 1)

print(suma.dtype)
print(suma.min())
print(suma.max())

plt.imshow(suma)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (300, 451, 3)
# (300, 451, 3)
# float64
# float64
# 0.00392156862745098
# 1.815686274509804
